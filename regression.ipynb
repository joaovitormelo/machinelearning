# %%
#APRENDIZADO DE REGRESSÃO LINEAR
import pandas as pd
import quandl
import math
from sklearn import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_46776/1024264743.py in <module>
#       3 import quandl
#       4 import math
# ----> 5 from sklearn import preprocessing
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
original = quandl.get('WIKI/GOOGL')

# %%
df = original.copy()
df['PCT_Volatility'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Low'] * 100
df['PCT_Change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100
df = df[['Adj. Close', 'PCT_Volatility', 'PCT_Change', 'Adj. Volume']]

# %%
#PROCESS OF LABEL CREATION. WE HAVE A SET OF FEATURES, AND WANT TO CONVERT, IN THAT CASE, ONE OF THEM INTO LABELS
#THE IDEA IS TO ATTRIBUTE THE Adj. Close COLUMN A forecast_out AMOUNT OF DAYS IN THE FUTURE AS THE LABEL FOR TODAY.
#FROM THAT, WE CREATE A LABELED DATASET TO TRAIN OUR MODEL, THAT WILL TRY TO PREDICT THE Adj. Close forecast_out DAYS IN THE
#FUTURE BASED ON THESE FEATURES WE'VE SELECTED
invalid = -99999
forecast_col = 'Adj. Close'
df.fillna(invalid, inplace=True)
forecast_out = int(math.ceil(0.01 * len(df)))
df["label"] = df[forecast_col].shift(-forecast_out)
df.dropna(inplace=True)

# %%
df
# Out:
#             Adj. Close  PCT_Volatility  PCT_Change  Adj. Volume       label
# Date
# 2004-08-19   50.322842        8.441017    0.324968   44659000.0   67.739104
# 2004-08-20   54.322689        8.537313    7.227007   22834300.0   69.399229
# 2004-08-23   54.869377        4.062357   -1.227880   18256100.0   68.752232
# 2004-08-24   52.597363        7.753210   -5.726357   15247300.0   69.639972
# 2004-08-25   53.164113        3.966115    1.183658    9188600.0   69.078238
# ...                ...             ...         ...          ...         ...
# 2016-09-22  815.950000        1.405207    0.734568    1759290.0  781.100000
# 2016-09-23  814.960000        0.525390   -0.022082    1411673.0  802.030000
# 2016-09-26  802.650000        1.203073   -0.885382    1472732.0  811.980000
# 2016-09-27  810.730000        1.454174    1.109961    1367271.0  805.590000
# 2016-09-28  810.060000        0.930479    0.743707    1470280.0  780.290000
#
# [3050 rows x 5 columns]
